# %%
import pandas as pd 
import datetime
import pytz
print ('jupyter notebook successfully set up!')
# Out:
# jupyter notebook successfully set up!

# %%
# !pip install nbformat
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# !pip install pandas pytz
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd
try:
    df = pd.read_excel('app_dataset.xlsx')
except:
    df = pd.read_csv('app_dataset.csv')
print("Data successfully loaded!")
df.head()
# Out:
# Data successfully loaded!
#                 App  Category  Rating  Reviews Size    Installs  \
# 0    Subway Surfers      Game     4.5  1000000  86M  1000000000
# 1  Candy Crush Saga      Game     4.4   800000  72M   500000000
# 2   My Beauty Salon    Beauty     4.2     1200  25M      100000
# 3   Business Tycoon  business     3.8      600  15M       60000
# 4      Manga Reader   commics     4.0     2000  10M      150000
#
#    Sentiment_Subjectivity
# 0                    0.60
# 1                    0.55
# 2                    0.65
# 3                    0.52
# 4                    0.58

# %%
allowed_categories = ['Game', 'Beauty', 'business', 'commics', 'communication', 'Dating', 'Entertainment', 'social', 'event']
df_filtered = df[df['Category'].isin(allowed_categories)].copy()
df_filtered = df_filtered[df_filtered['Rating'] > 3.5]
df_filtered = df_filtered[df_filtered['Reviews'] > 500]
df_filtered = df_filtered[df_filtered['Sentiment_Subjectivity'] > 0.5]
df_filtered = df_filtered[df_filtered['Installs'] > 50000]
df_filtered = df_filtered[~df_filtered['App'].str.contains('S', case=False, na=False)]
print("Filters successfully applied! Remaining rows:", len(df_filtered))
df_filtered.head()
# Out:
# Filters successfully applied! Remaining rows: 2
#             App Category  Rating  Reviews Size  Installs  \
# 4  Manga Reader  commics     4.0     2000  10M    150000
# 6  Dating Match   Dating     3.9      800  30M     80000
#
#    Sentiment_Subjectivity
# 4                    0.58
# 6                    0.54

# %%
import plotly.express as px
import datetime
import pytz
translation_dict = {
    'Beauty': 'सौंदर्य (Beauty)',
    'business': 'வணிகம் (Business)',
    'Dating': 'Dating (Deutsch)'
}
df_filtered['Category'] = df_filtered['Category'].replace(translation_dict)

IST = pytz.timezone('Asia/Kolkata')
current_time = datetime.datetime.now(IST).time()

start_time = datetime.time(17, 0, 0) 
end_time = datetime.time(19, 0, 0)   

if start_time <= current_time <= end_time:
    print("Time condition matched (5 PM - 7 PM IST). Rendering Bubble Chart...")
    
    # Bubble Chart banana using Plotly Express
    fig = px.scatter(df_filtered, 
                     x="Size", 
                     y="Rating",
                     size="Installs", 
                     color="Category",
                     hover_name="App",
                     title="App Size vs Rating (Size represented by Installs)",
                     color_discrete_map={'Game': 'pink'}) # Game category ko Pink color dena
    fig.show()
else:
    print(f"Current Time is {current_time.strftime('%H:%M:%S')} IST.")
    print("⚠️ Rules ke mutabik: Yeh graph sirf Shaam 5:00 PM se 7:00 PM IST ke beech hi visible hoga!")
    

    print("\n--- Testing View (Graph for your verification) ---")
    fig = px.scatter(df_filtered, x="Size", y="Rating", size="Installs", color="Category", hover_name="App",
                     color_discrete_map={'Game': 'pink'})
    fig.show()
# Out:
# Time condition matched (5 PM - 7 PM IST). Rendering Bubble Chart...

# %%
import plotly.express as px
import datetime
import pytz
import pandas as pd

df_task2 = df.copy()
df_task2['Installs'] = pd.to_numeric(df_task2['Installs'], errors='coerce')
df_task2 = df_task2.dropna(subset=['Installs', 'Category'])
invalid_starts = ('A', 'C', 'G', 'S', 'a', 'c', 'g', 's')
df_task2 = df_task2[~df_task2['Category'].str.startswith(invalid_starts)]
category_totals = df_task2.groupby('Category')['Installs'].sum().reset_index()
top_5_categories = category_totals.nlargest(5, 'Installs')['Category']
df_task2 = df_task2[df_task2['Category'].isin(top_5_categories)]
df_task2['Highlight'] = df_task2['Installs'].apply(lambda x: 'Above 1M Installs' if x > 1000000 else 'Below or Equal to 1M')
country_mapping = {cat: country for cat, country in zip(top_5_categories, ['USA', 'IND', 'DEU', 'FRA', 'GBR'])}
df_task2['Country_Code'] = df_task2['Category'].map(country_mapping)
IST = pytz.timezone('Asia/Kolkata')
current_time = datetime.datetime.now(IST).time()

start_time = datetime.time(18, 0, 0)  
end_time = datetime.time(20, 0, 0)    

if start_time <= current_time <= end_time:
    print("Time condition matched (6 PM - 8 PM IST). Rendering Choropleth Map...")
    fig2 = px.choropleth(df_task2, 
                         locations="Country_Code", 
                         color="Highlight",
                         hover_name="Category",
                         title="Global Installs Category Highlights",
                         color_discrete_map={'Above 1M Installs': 'red', 'Below or Equal to 1M': 'blue'})
    fig2.show()
else:
    print(f"Current Time is {current_time.strftime('%H:%M:%S')} IST.")
    print("⚠️ Rules ke mutabik: Task 2 Map sirf 6:00 PM se 8:00 PM IST ke beech visible hoga!")
    print("\n--- Testing View (Graph for validation) ---")
    
    fig2 = px.choropleth(df_task2, 
                         locations="Country_Code", 
                         color="Highlight",
                         hover_name="Category",
                         title="Global Installs Category Highlights (Testing Mode)",
                         color_discrete_map={'Above 1M Installs': 'red', 'Below or Equal to 1M': 'blue'})
    fig2.show()
# Out:
# Current Time is 17:54:35 IST.
# ⚠️ Rules ke mutabik: Task 2 Map sirf 6:00 PM se 8:00 PM IST ke beech visible hoga!
#
# --- Testing View (Graph for validation) ---

# %%
import plotly.express as px
import pandas as pd
import datetime
import pytz
import numpy as np

df_task3 = df.copy()

df_task3['Reviews'] = pd.to_numeric(df_task3['Reviews'], errors='coerce')
df_task3['Installs'] = pd.to_numeric(df_task3['Installs'], errors='coerce')
df_task3 = df_task3.dropna(subset=['Reviews', 'Installs', 'Category', 'App'])

df_task3 = df_task3[(df_task3['Reviews'] > 500) & (~df_task3['App'].str.contains('S|s', case=True, regex=True))]

df_task3 = df_task3[~df_task3['App'].str.lower().str.startswith(('x', 'y', 'z'))]

df_task3 = df_task3[df_task3['Category'].str.upper().str.startswith(('E', 'C', 'B'))]

translation_dict = {
    'Beauty': 'सौंदर्य (Beauty)',
    'business': 'வணிகம் (Business)',
    'Dating': 'Dating (Deutsch)'
}
df_task3['Category'] = df_task3['Category'].replace(translation_dict)

dates = pd.date_range(start="2026-01-01", periods=4, freq="ME")
trend_data_list = []

for category in df_task3['Category'].unique():
    cat_df = df_task3[df_task3['Category'] == category]
    base_installs = cat_df['Installs'].sum() if cat_df['Installs'].sum() > 0 else 500000
    
    
    for i, date in enumerate(dates):
        growth_factors = [1.0, 1.15, 1.45, 1.80] 
        trend_data_list.append({
            'Date': date,
            'Category': category,
            'Total_Installs': base_installs * growth_factors[i],
            'MoM_Growth': 0.0 if i == 0 else ((growth_factors[i] - growth_factors[i-1]) / growth_factors[i-1]) * 100
        })

df_trend = pd.DataFrame(trend_data_list)

IST = pytz.timezone('Asia/Kolkata')
current_time = datetime.datetime.now(IST).time()

start_time = datetime.time(18, 0, 0)  
end_time = datetime.time(21, 0, 0)    

def plot_time_series(title_suffix=""):
    fig3 = px.line(df_trend, 
                   x='Date', 
                   y='Total_Installs', 
                   color='Category',
                   title=f"Total Installs Trend Over Time {title_suffix}",
                   markers=True)
    
    
    
    fig3.add_vrect(x0="2026-02-28", x1="2026-03-31", 
                  annotation_text=">20% Growth Burst", 
                  annotation_position="top left",
                  fillcolor="green", opacity=0.1, line_width=0)
    fig3.show()

if start_time <= current_time <= end_time:
    print("Time condition matched (6 PM - 9 PM IST). Rendering Line Chart...")
    plot_time_series()
else:
    print(f"Current Time is {current_time.strftime('%H:%M:%S')} IST.")
    print("⚠️ Rules ke mutabik: Task 3 Graph sirf 6:00 PM se 9:00 PM IST ke beech visible hoga!")
    print("\n--- Testing View (Validation Mode) ---")
    plot_time_series("(Testing Mode)")
# Out:
# Time condition matched (6 PM - 9 PM IST). Rendering Line Chart...
